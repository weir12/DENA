# %%
from feature_selector import FeatureSelector

import pandas as pd
train = pd.read_csv('./RNN_features.txt',sep="\t")
train
# Out:
#          base_q_-7  base_q_-6  base_q_-5  base_q_-4  base_q_-3  base_q_-2  \
# 0             17.0       19.0       20.0       20.0       22.0       22.0
# 1             15.0       18.0       19.0       19.0       19.0       20.0
# 2              5.0        0.0        0.0       14.0       14.0       16.0
# 3             16.0        0.0       16.0       17.0       17.0       17.0
# 4              8.0        0.0        9.0        9.0        9.0       10.0
# ...            ...        ...        ...        ...        ...        ...
# 2251830       13.0       14.0       23.0       14.0       13.0       14.0
# 2251831       22.0       25.0       17.0       17.0       17.0       20.0
# 2251832       34.0       33.0       30.0       29.0       28.0       30.0
# 2251833       28.0       30.0       19.0       29.0       26.0       30.0
# 2251834       10.0        8.0       13.0       10.0        8.0       20.0
#
#          base_q_-1  base_q_0  base_q_1  base_q_2  ...     sd_-1      sd_0  \
# ...

# %%
train
# Out:
#          base_q_-7  base_q_-6  base_q_-5  base_q_-4  base_q_-3  base_q_-2  \
# 0             17.0       19.0       20.0       20.0       22.0       22.0
# 1             15.0       18.0       19.0       19.0       19.0       20.0
# 2              5.0        0.0        0.0       14.0       14.0       16.0
# 3             16.0        0.0       16.0       17.0       17.0       17.0
# 4              8.0        0.0        9.0        9.0        9.0       10.0
# ...            ...        ...        ...        ...        ...        ...
# 2251830       13.0       14.0       23.0       14.0       13.0       14.0
# 2251831       22.0       25.0       17.0       17.0       17.0       20.0
# 2251832       34.0       33.0       30.0       29.0       28.0       30.0
# 2251833       28.0       30.0       19.0       29.0       26.0       30.0
# 2251834       10.0        8.0       13.0       10.0        8.0       20.0
#
#          base_q_-1  base_q_0  base_q_1  base_q_2  ...     sd_-1      sd_0  \
# ...
